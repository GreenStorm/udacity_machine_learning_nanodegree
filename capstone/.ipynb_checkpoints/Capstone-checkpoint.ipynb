# %% [markdown]
# ## **II. Analysis**
#
# *(approx. 2-4 pages)*
#
# ### **Data Exploration**
#
# In this section, you will be expected to analyze the data you are using for the problem. This data can either be in the form of a dataset (or datasets), input data (or input files), or even an environment. The type of data should be thoroughly described and, if possible, have basic statistics and information presented (such as discussion of input features or defining characteristics about the input or environment). Any abnormalities or interesting qualities about the data that may need to be addressed have been identified (such as features that need to be transformed or the possibility of outliers). Questions to ask yourself when writing this section:
#
# * *If a dataset is present for this problem, have you thoroughly discussed certain features about the dataset? Has a data sample been provided to the reader?*
#
# * *If a dataset is present for this problem, are statistics about the dataset calculated and reported? Have any relevant results from this calculation been discussed?*
#
# * *If a dataset is not present for this problem, has discussion been made about the input space or input data for your problem?*
#
# * *Are there any abnormalities or characteristics about the input space or dataset that need to be addressed? (categorical variables, missing values, outliers, etc.)*

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    nuclei_files = np.array(glob(path+'/*/images/*'))
    nuclei_targets = np.array(glob(path+'/*/masks/*'))
    return nuclei_files,nuclei_targets

train_files,train_targets = load_dataset('stage1_train/')
test_files,test_targets= load_dataset('stage1_test/')

#TODO: pick a better represntation of a validation set

print('There are %d training batch nuecli images.' % len(train_files))
print('There are %d training batch nuecli masks.' % len(train_targets))
# Out:
# Using TensorFlow backend.
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# There are 670 training batch nuecli images.
# There are 29461 training batch nuecli masks.

# %%
# Binding masks with the parent image:
import os.path

def get_filename(path):
    return os.path.splitext(os.path.basename(path))[0]

def bind_mask_to_images(images_paths, masks_paths):
    image_id = 0
    filename = get_filename(images_paths[0])
    masks_binded = [[]]
    for mask_path in masks_paths:
        if filename in mask_path:
            masks_binded[image_id].append(mask_path)
        else:
            image_id = image_id+1
            filename = get_filename(images_paths[image_id])
            masks_binded.append([mask_path])
    return np.array(masks_binded)

    
train_targets_binded = bind_mask_to_images(train_files,train_targets)
#train_targets_merged = merge_masks(train_targets_binded)

print("Train targets have been binded")
# Out:
# Train targets have been binded

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# load color (BGR) image
img = cv2.imread(train_files[3])
# convert BGR image to grayscale
gray = cv2.imread(train_files[3],0)


#from skimage.color import rgb2gray
#im_gray = rgb2gray(img)

plt.subplot(1,2,1)
plt.imshow(img)
plt.title("Original image")
plt.subplot(1,2,2)
plt.title("Greyscaled image")
plt.imshow(gray)
plt.show()
#pixel intensity for image
plt.hist(gray.ravel(),256,[0,256])
plt.title("Pixel intensity of the image")
plt.show()

# %% [markdown]
# ### Sources:
# - https://docs.opencv.org/3.1.0/d1/db7/tutorial_py_histogram_begins.html
# - https://www.pyimagesearch.com/2014/05/26/opencv-python-k-means-color-clustering/
# - dog-project

# %%
from sklearn.cluster import KMeans
import random

seed = random.seed(8675309)
def find_dominant_color_in_image(image,number_of_clusters):
    # re-shape our image to be a list of pixels, rather than MxN matrix of pixels
    image = image.reshape((image.shape[0] * image.shape[1], 3))
    color_clf = KMeans(random_state=seed,n_clusters = number_of_clusters)
    color_clf.fit(image)
    
    return color_clf.cluster_centers_

def cluster_images_based_on_color(images_path_array,number_of_clusters,number_of_colors):
    dominant_colors = []
    for image_path in images_path_array:
        image = cv2.imread(image_path)
        colors_in_image = find_dominant_color_in_image(image,number_of_colors)
        dominant_colors.append(colors_in_image.flatten())
    #print(image)
    #print(dominant_colors)
    img_clf = KMeans(random_state=seed,n_clusters = number_of_clusters)
    img_clf.fit(np.array(dominant_colors))
    return img_clf

def plot_color_bar(colors):
    bar = np.zeros((50, 300, 3), dtype = "uint8")
    startX = 0
    for color in colors:
        #print ("color in bar",color)
        endX = startX + (1/len(colors) * 300)
        #print("the start is",startX, 'the end is',endX)
        cv2.rectangle(bar, (int(startX), 0), (int(endX), 50),color.astype("uint8").tolist(), -1)
        startX = endX
    plt.figure()
    plt.axis("off")
    plt.imshow(bar)
    plt.show()
    return bar

# %%
number_of_colors = 3
images_clf = cluster_images_based_on_color(train_files,3,number_of_colors)

# %%
colors_clusters = images_clf.cluster_centers_
labels = images_clf.labels_
print(len(labels))
RGB_COLORS_CONSTANT = 3
if(number_of_colors>1):
    for color in colors_clusters:
        plot_color_bar(np.split(color,RGB_COLORS_CONSTANT))
else:
    for color in colors_clusters:
        plot_color_bar(color)
# Out:
# 670

# %% [markdown]
# ## Colors and Stains:
#
# We can observe from the previous clusters that the dataset is stained differently, the differences in coloring. Hence, we'll be using grayscale?

# %%
#print (images_clf)
sample_image = cv2.imread(train_files[0])
#print (sample_image.shape[1])
def get_images_features_list(images_path_array):
    images_height = []
    images_width = []
    images_mean = []
    images_std= []
    for image_path in images_path_array:
        image = cv2.imread(image_path)
        images_height.append(image.shape[0])
        images_width.append(image.shape[1])
        images_mean.append(np.mean(image))
        images_std.append(np.std(image))
    return images_height,images_width,images_mean,images_std

def plot_scatter_plot(X,y):
    plt.xlabel("Height (px)")
    plt.ylabel("Width (px)")
    plt.title("Resolution Scatter Plot")
    plt.scatter(X, y)
    
X,y,means,stdvs = get_images_features_list(train_files)
plot_scatter_plot(X,y)

# %%
heatmap, xedges, yedges = np.histogram2d(X, y, bins=10)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.imshow(heatmap.T, extent=extent, origin='lower')
plt.show()

paired = (list(zip(X,y)))

# %%
import pandas as pd
import seaborn as sns

df = pd.DataFrame(data=paired)
#print(df.keys)
df.index.name = 'x label'

ax = df.plot.hexbin(x=0, y=1, gridsize=5,title="Resolution Heatmap",)
ax.set_ylabel("Width (px)")
ax.set_xlabel("Height (px)") #bug in juypter notebook doens't show the x-axis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-124b60ee12ac> in <module>()
#       2 import seaborn as sns
#       3
# ----> 4 df = pd.DataFrame(data=paired)
#       5 #print(df.keys)
#       6 df.index.name = 'x label'
#
# NameError: name 'paired' is not defined

# %%
#Plot "Pixel Intensity Means for All Images" and "Standard Deviation per Image"

plt.plot(means, np.zeros_like(means), 'x')
plt.xlabel("Image mean (px)")
plt.title("Pixel Intensity Means for All Images")
plt.axes().get_yaxis().set_visible(False)
plt.show()
plt.plot(stdvs, np.zeros_like(stdvs), 'r+')
plt.title("Images Standard Deviation")
plt.axes().get_yaxis().set_visible(False)
plt.xlabel("Standard Deviation per Image (px)")
plt.show()

# %% [markdown]
# ## Preprocessing:

# %%
#Taken from dog-project, Preprocessing for Keras
from keras.preprocessing import image as KImage                  
from tqdm import tqdm
from PIL import ImageFile                            
from skimage import io, img_as_float
from skimage.transform import resize
from skimage.color import rgb2gray,rgba2rgb

img_height, img_width = 224,224

#Doesn't work shows target fully black.
def old_path_to_image(img_path):
    # loads RGB image as PIL.Image.Image type
    img = KImage.load_img(img_path, target_size=(img_height, img_width))
    # convert PIL.Image.Image type to 3D tensor with shape (150, 150, 3)
    image_array = KImage.img_to_array(img)
    return image_array

def path_to_image(img_path):
    image = io.imread(img_path)
    #transform image to  height and width to match model requirements
    image = resize(image, (img_height, img_width), mode='constant')
    #rgba to rgb
    try:
        image = rgba2rgb(image)
    except:
        if(len(image.shape)<3):
            image = np.expand_dims(image,axis=-1)
    image = img_as_float(image)
    return image

def path_to_tensor(img_path):
    x = path_to_image(img_path)
    return image_to_tensor(x)

def image_to_tensor(img):
    # convert 3D tensor to 4D tensor with shape (1, 150, 150, 3) and return 4D tensor
    return np.expand_dims(img, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    #print(list_of_tensors[0])
    return np.vstack(list_of_tensors)

def images_to_tensor(img_list):
    list_of_tensors = [image_to_tensor(img_list) for img_list in tqdm(img_list)]
    #print(list_of_tensors[0])
    return np.vstack(list_of_tensors)

# %%
def merge_masks(train_targets_binded):
    bigboy = []
    for binder in (train_targets_binded):
        merged_mask = np.zeros_like(path_to_image(binder[0]))##.astype('float32')/255 ?
        for mask_path in binder:
            mask = path_to_image(mask_path)
            merged_mask = np.maximum(merged_mask,mask)
        binder = merged_mask
        bigboy.append(merged_mask)
    return bigboy

# %%
#ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras, since we need to match the pre-trained enviroment
train_files_tensors = paths_to_tensor(train_files)

train_targets_merged = merge_masks(train_targets_binded)
#print(train_targets_merged[0])
train_target_tensors = images_to_tensor(train_targets_merged)

print(train_files.shape)
print(train_targets_binded.shape)
#print(train_targets_merged.shape)
print(train_files_tensors.shape)
print(train_target_tensors.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 670/670 [00:11<00:00, 57.79it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 670/670 [00:00<00:00, 668136.87it/s]
# (670,)
# (670,)
# (670, 224, 224, 3)
# (670, 224, 224, 1)

# %% [markdown]
# ### Sanity Check:

# %%
def plot_image(img):
    print(img.shape)
    plt.imshow(np.squeeze(img))
    #print(img)
    plt.show()
    
plot_image(train_files_tensors[1])
plot_image(train_target_tensors[1])
s = path_to_image(train_files[1])
#s = np.expand_dims(train_files_tensors[1], axis=-1)
plot_image(s)
#print(range(train_files_tensors.shape[:1][0]-1))
# Out:
# (224, 224, 3)
# (224, 224, 1)
# (224, 224, 3)

# %% [markdown]
# ### Model:

# %%
from keras.applications.xception import Xception, preprocess_input
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Conv2DTranspose
from keras.layers import Dropout, Flatten, Dense, Reshape
from keras.models import Sequential,Model

#TODO bottleneck_features
base_model = Xception(input_shape=train_files_tensors.shape[1:],weights='imagenet', include_top=False)

xc = base_model.output
output= Conv2DTranspose(3, (3, 3), strides=(30, 30), padding='same',activation='relu')(xc)

Xception_starter_model = Model(base_model.input, output)

for layer in Xception_starter_model.layers[:132]:
    layer.trainable = False

print(Xception_starter_model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, 111, 111, 32)  864
# ____________________________________________________________________________________________________
# block1_conv1_bn (BatchNormalizat (None, 111, 111, 32)  128
# ____________________________________________________________________________________________________
# block1_conv1_act (Activation)    (None, 111, 111, 32)  0
# ____________________________________________________________________________________________________
# block1_conv2 (Conv2D)            (None, 109, 109, 64)  18432
# ____________________________________________________________________________________________________
# block1_conv2_bn (BatchNormalizat (None, 109, 109, 64)  256
# ____________________________________________________________________________________________________
# block1_conv2_act (Activation)    (None, 109, 109, 64)  0
# ____________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2D (None, 109, 109, 128) 8768
# ____________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormali (None, 109, 109, 128) 512
# ____________________________________________________________________________________________________
# block2_sepconv2_act (Activation) (None, 109, 109, 128) 0
# ____________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2D (None, 109, 109, 128) 17536
# ____________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormali (None, 109, 109, 128) 512
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 55, 55, 128)   8192
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 55, 55, 128)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 55, 55, 128)   512
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 55, 55, 128)   0
# ____________________________________________________________________________________________________
# block3_sepconv1_act (Activation) (None, 55, 55, 128)   0
# ____________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2D (None, 55, 55, 256)   33920
# ____________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormali (None, 55, 55, 256)   1024
# ____________________________________________________________________________________________________
# block3_sepconv2_act (Activation) (None, 55, 55, 256)   0
# ____________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2D (None, 55, 55, 256)   67840
# ____________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormali (None, 55, 55, 256)   1024
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 28, 28, 256)   32768
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 28, 28, 256)   0
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 28, 28, 256)   1024
# ____________________________________________________________________________________________________
# add_2 (Add)                      (None, 28, 28, 256)   0
# ____________________________________________________________________________________________________
# block4_sepconv1_act (Activation) (None, 28, 28, 256)   0
# ____________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2D (None, 28, 28, 728)   188672
# ____________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormali (None, 28, 28, 728)   2912
# ____________________________________________________________________________________________________
# block4_sepconv2_act (Activation) (None, 28, 28, 728)   0
# ____________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2D (None, 28, 28, 728)   536536
# ____________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormali (None, 28, 28, 728)   2912
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 14, 14, 728)   186368
# ____________________________________________________________________________________________________
# block4_pool (MaxPooling2D)       (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_3 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block5_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block5_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_4 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block6_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block6_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_5 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block7_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block7_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_6 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block8_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block8_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_7 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block9_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block9_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_8 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block10_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block10_sepconv3_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_9 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block11_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block11_sepconv3_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_10 (Add)                     (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block12_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block12_sepconv3_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_11 (Add)                     (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block13_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block13_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv2 (None, 14, 14, 1024)  752024
# ____________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNormal (None, 14, 14, 1024)  4096
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 7, 7, 1024)    745472
# ____________________________________________________________________________________________________
# block13_pool (MaxPooling2D)      (None, 7, 7, 1024)    0
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 7, 7, 1024)    4096
# ____________________________________________________________________________________________________
# add_12 (Add)                     (None, 7, 7, 1024)    0
# ____________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv2 (None, 7, 7, 1536)    1582080
# ____________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNormal (None, 7, 7, 1536)    6144
# ____________________________________________________________________________________________________
# block14_sepconv1_act (Activation (None, 7, 7, 1536)    0
# ____________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv2 (None, 7, 7, 2048)    3159552
# ____________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNormal (None, 7, 7, 2048)    8192
# ____________________________________________________________________________________________________
# block14_sepconv2_act (Activation (None, 7, 7, 2048)    0
# ____________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTransp (None, 210, 210, 3)   55299
# ====================================================================================================
# Total params: 20,916,779.0
# Trainable params: 55,299.0
# Non-trainable params: 20,861,480.0
# ____________________________________________________________________________________________________
# None

# %%
xc = base_model.output

ct1 = Conv2DTranspose(729, (2, 2), strides=(2, 2), padding='same',activation='relu')(xc)
c6 = Conv2D(729, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(ct1)
c6 = Dropout(0.2)(c6)
c6 = Conv2D(729, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c6)
ct2 = Conv2DTranspose(81, (2, 2), strides=(3, 3), padding='same',activation='relu')(c6)
c7 = Conv2D(81, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(ct2)
c7 = Dropout(0.2)(c7)
c7 = Conv2D(81, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c7)
output = Conv2DTranspose(1, (2, 2), strides=(5, 5), padding='same',activation='relu')(c7)

Xception_intermid_model = Model(base_model.input, output)

# freeze Xception layers
for layer in Xception_intermid_model.layers[:132]:
    layer.trainable = False

print(Xception_intermid_model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, 111, 111, 32)  864
# ____________________________________________________________________________________________________
# block1_conv1_bn (BatchNormalizat (None, 111, 111, 32)  128
# ____________________________________________________________________________________________________
# block1_conv1_act (Activation)    (None, 111, 111, 32)  0
# ____________________________________________________________________________________________________
# block1_conv2 (Conv2D)            (None, 109, 109, 64)  18432
# ____________________________________________________________________________________________________
# block1_conv2_bn (BatchNormalizat (None, 109, 109, 64)  256
# ____________________________________________________________________________________________________
# block1_conv2_act (Activation)    (None, 109, 109, 64)  0
# ____________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2D (None, 109, 109, 128) 8768
# ____________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormali (None, 109, 109, 128) 512
# ____________________________________________________________________________________________________
# block2_sepconv2_act (Activation) (None, 109, 109, 128) 0
# ____________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2D (None, 109, 109, 128) 17536
# ____________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormali (None, 109, 109, 128) 512
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 55, 55, 128)   8192
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 55, 55, 128)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 55, 55, 128)   512
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 55, 55, 128)   0
# ____________________________________________________________________________________________________
# block3_sepconv1_act (Activation) (None, 55, 55, 128)   0
# ____________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2D (None, 55, 55, 256)   33920
# ____________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormali (None, 55, 55, 256)   1024
# ____________________________________________________________________________________________________
# block3_sepconv2_act (Activation) (None, 55, 55, 256)   0
# ____________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2D (None, 55, 55, 256)   67840
# ____________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormali (None, 55, 55, 256)   1024
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 28, 28, 256)   32768
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 28, 28, 256)   0
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 28, 28, 256)   1024
# ____________________________________________________________________________________________________
# add_2 (Add)                      (None, 28, 28, 256)   0
# ____________________________________________________________________________________________________
# block4_sepconv1_act (Activation) (None, 28, 28, 256)   0
# ____________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2D (None, 28, 28, 728)   188672
# ____________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormali (None, 28, 28, 728)   2912
# ____________________________________________________________________________________________________
# block4_sepconv2_act (Activation) (None, 28, 28, 728)   0
# ____________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2D (None, 28, 28, 728)   536536
# ____________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormali (None, 28, 28, 728)   2912
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 14, 14, 728)   186368
# ____________________________________________________________________________________________________
# block4_pool (MaxPooling2D)       (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_3 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block5_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block5_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_4 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block6_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block6_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_5 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block7_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block7_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_6 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block8_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block8_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_7 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv1_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block9_sepconv2_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block9_sepconv3_act (Activation) (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2D (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormali (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_8 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block10_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block10_sepconv3_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_9 (Add)                      (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block11_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block11_sepconv3_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_10 (Add)                     (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block12_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block12_sepconv3_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# add_11 (Add)                     (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block13_sepconv1_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv2 (None, 14, 14, 728)   536536
# ____________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNormal (None, 14, 14, 728)   2912
# ____________________________________________________________________________________________________
# block13_sepconv2_act (Activation (None, 14, 14, 728)   0
# ____________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv2 (None, 14, 14, 1024)  752024
# ____________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNormal (None, 14, 14, 1024)  4096
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 7, 7, 1024)    745472
# ____________________________________________________________________________________________________
# block13_pool (MaxPooling2D)      (None, 7, 7, 1024)    0
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 7, 7, 1024)    4096
# ____________________________________________________________________________________________________
# add_12 (Add)                     (None, 7, 7, 1024)    0
# ____________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv2 (None, 7, 7, 1536)    1582080
# ____________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNormal (None, 7, 7, 1536)    6144
# ____________________________________________________________________________________________________
# block14_sepconv1_act (Activation (None, 7, 7, 1536)    0
# ____________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv2 (None, 7, 7, 2048)    3159552
# ____________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNormal (None, 7, 7, 2048)    8192
# ____________________________________________________________________________________________________
# block14_sepconv2_act (Activation (None, 7, 7, 2048)    0
# ____________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTransp (None, 14, 14, 729)   5972697
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 14, 14, 729)   4783698
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 14, 14, 729)   0
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 14, 14, 729)   4783698
# ____________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTransp (None, 42, 42, 81)    236277
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 42, 42, 81)    59130
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 42, 42, 81)    0
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 42, 42, 81)    59130
# ____________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTransp (None, 210, 210, 1)   325
# ====================================================================================================
# Total params: 36,756,435.0
# Trainable params: 15,894,955.0
# Non-trainable params: 20,861,480.0
# ____________________________________________________________________________________________________
# None

# %% [markdown]
# ### Metric:

# %%
#Taken from https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277#295658

def meanIoU(y_true_batch, y_pred_batch):
    return np.mean(np.asarray([IoU(y_pred_batch, y_true_batch,t) for t in np.arange(0.5, 1, 0.05)])) 

def IoU(y_pred_batch, y_true_batch, threshold):
    pxArray = []
    for i in range(100):
        print(i)
        px = pixelAccuracy(y_pred_batch[i], y_true_batch[i],threshold)
        pxArray.append(px)
    
    return pxArray

def pixelAccuracy(y_pred_orig, y_true, threshold):
    print(y_pred_orig, y_true, threshold)
    y_pred = wrap_booleans(y_pred_orig > threshold)
    #true positive / (true positive + false positive + false negative)
    
    return 1.0 * np.sum(wrap_booleans(y_pred==y_true)*wrap_booleans(y_true>0)) /  (np.sum(wrap_booleans(y_pred>0)) + np.sum(wrap_booleans(y_true>0)) - np.sum(wrap_booleans(y_pred==y_true))*wrap_booleans(y_true>0))

def wrap_booleans (exp):
    if exp: return 1
    else: return 0

# %%
# Metric function, taken from https://github.com/kamalkraj/DATA-SCIENCE-BOWL-2018/blob/master/Data_Science_Bowl_2018.ipynb
from keras import backend as K
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Loss funtion
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# ### Compile:

# %%
Xception_intermid_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=[dice_coef,meanIoU])
# Out:
# WARNING:tensorflow:From D:\Kareem\Conda\envs\dog-project\lib\site-packages\keras\backend\tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From D:\Kareem\Conda\envs\dog-project\lib\site-packages\keras\backend\tensorflow_backend.py:1044: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# 0
# Tensor("strided_slice:0", shape=(?, ?, 1), dtype=float32) Tensor("strided_slice_1:0", shape=(?, ?, ?), dtype=float32) 0.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1b7732c7eca6> in <module>()
# ----> 1 Xception_intermid_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=[dice_coef,meanIoU])
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\keras\engine\training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, **kwargs)
#     954                     metric_fn = metrics_module.get(metric)
#     955                     masked_metric_fn = _masked_objective(metric_fn)
# --> 956                     metric_result = masked_metric_fn(y_true, y_pred, mask=masks[i])
#     957                     metric_result = {
#     958                         metric_fn.__name__: metric_result
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\keras\engine\training.py in masked(y_true, y_pred, mask)
#     477         """
#     478         # score_array has ndim >= 2
# --> 479         score_array = fn(y_true, y_pred)
#     480         if mask is not None:
#     481             # Cast the mask to floatX to avoid float64 upcasting in theano
#
# <ipython-input-10-ff96a71e0e6c> in meanIoU(y_true_batch, y_pred_batch)
#       2
#       3 def meanIoU(y_true_batch, y_pred_batch):
# ----> 4     return np.mean(np.asarray([IoU(y_pred_batch, y_true_batch,t) for t in np.arange(0.5, 1, 0.05)]))
#       5
#       6 def IoU(y_pred_batch, y_true_batch, threshold):
#
# <ipython-input-10-ff96a71e0e6c> in <listcomp>(.0)
#       2
#       3 def meanIoU(y_true_batch, y_pred_batch):
# ----> 4     return np.mean(np.asarray([IoU(y_pred_batch, y_true_batch,t) for t in np.arange(0.5, 1, 0.05)]))
#       5
#       6 def IoU(y_pred_batch, y_true_batch, threshold):
#
# <ipython-input-10-ff96a71e0e6c> in IoU(y_pred_batch, y_true_batch, threshold)
#       8     for i in range(100):
#       9         print(i)
# ---> 10         px = pixelAccuracy(y_pred_batch[i], y_true_batch[i],threshold)
#      11         pxArray.append(px)
#      12
#
# <ipython-input-10-ff96a71e0e6c> in pixelAccuracy(y_pred_orig, y_true, threshold)
#      15 def pixelAccuracy(y_pred_orig, y_true, threshold):
#      16     print(y_pred_orig, y_true, threshold)
# ---> 17     y_pred = wrap_booleans(y_pred_orig > threshold)
#      18     #true positive / (true positive + false positive + false negative)
#      19
#
# <ipython-input-10-ff96a71e0e6c> in wrap_booleans(exp)
#      21
#      22 def wrap_booleans (exp):
# ---> 23     if exp: return 1
#      24     else: return 0
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\tensorflow\python\framework\ops.py in __bool__(self)
#     612       `TypeError`.
#     613     """
# --> 614     raise TypeError("Using a `tf.Tensor` as a Python `bool` is not allowed. "
#     615                     "Use `if t is not None:` instead of `if t:` to test if a "
#     616                     "tensor is defined, and use TensorFlow ops such as "
#
# TypeError: Using a `tf.Tensor` as a Python `bool` is not allowed. Use `if t is not None:` instead of `if t:` to test if a tensor is defined, and use TensorFlow ops such as tf.cond to execute subgraphs conditioned on the value of a tensor.

# %%
#print(train_files_tensors[9])

# %%
# taken from dog-project
from keras.callbacks import ModelCheckpoint,EarlyStopping

epochs = 50

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.xception_interim.hdf5', 
                               verbose=1, save_best_only=True)

Xception_intermid_model.fit(train_files_tensors, train_target_tensors, validation_split=0.1,
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-885cc99b7f1f> in <module>()
#       8
#       9 Xception_intermid_model.fit(train_files_tensors, train_target_tensors, validation_split=0.1,
# ---> 10           epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
#      11
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1403             class_weight=class_weight,
#    1404             check_batch_axis=False,
# -> 1405             batch_size=batch_size)
#    1406         # prepare validation data
#    1407         if validation_data:
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1297                                     output_shapes,
#    1298                                     check_batch_axis=False,
# -> 1299                                     exception_prefix='model target')
#    1300         sample_weights = _standardize_sample_weights(sample_weight,
#    1301                                                      self._feed_output_names)
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\keras\engine\training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     131                             ' to have shape ' + str(shapes[i]) +
#     132                             ' but got array with shape ' +
# --> 133                             str(array.shape))
#     134     return arrays
#     135
#
# ValueError: Error when checking model target: expected conv2d_transpose_4 to have shape (None, 210, 210, 1) but got array with shape (670, 224, 224, 1)

# %%
def detect_nuclei(predictor,img_path):
    # obtain predicted vector
    predicted_vector = predictor.predict(path_to_tensor(img_path))
    # return dog breed that is predicted by the model
    return predicted_vector

# %%
## Sanity Check:
predImage = detect_nuclei(Xception_intermid_model,train_files[0])
plot_image(path_to_image(train_files[0]))
plot_image(train_targets_merged[0])
plot_image(predImage[0])
# Out:
# (224, 224, 3)
# (224, 224, 1)
# (210, 210, 1)

# %%
#Taken from https://github.com/ZFTurbo/ZF_UNET_224_Pretrained_Model
from zf_unet_224_model import ZF_UNET_224, dice_coef_loss
from keras.optimizers import Adam

zf_unet_starter = ZF_UNET_224()
zf_unet_starter.load_weights("saved_models/zf_unet_224.h5") # optional
optim = Adam()
zf_unet_starter.summary()
zf_unet_starter.compile(optimizer=optim , loss=[dice_coef_loss], metrics=[dice_coef])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 224, 224, 32)      9248
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_2 (Activation)    (None, 224, 224, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 112, 112, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_3 (Activation)    (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_4 (Activation)    (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_5 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_6 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 28, 28, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 14, 14, 512)       1180160
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 7, 7, 1024)        4719616
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 7, 7, 1024)        4096
# _________________________________________________________________
# activation_11 (Activation)   (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 7, 7, 1024)        9438208
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 7, 7, 1024)        4096
# _________________________________________________________________
# activation_12 (Activation)   (None, 7, 7, 1024)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 14, 14, 1024)      0
# _________________________________________________________________
# concatenate_1 (Concatenate)  (None, 14, 14, 1536)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 14, 14, 512)       7078400
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_14 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 28, 28, 512)       0
# _________________________________________________________________
# concatenate_2 (Concatenate)  (None, 28, 28, 768)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 256)       1769728
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_15 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_16 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 56, 56, 256)       0
# _________________________________________________________________
# concatenate_3 (Concatenate)  (None, 56, 56, 384)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 56, 56, 128)       442496
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_17 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_18 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 112, 112, 128)     0
# _________________________________________________________________
# concatenate_4 (Concatenate)  (None, 112, 112, 192)     0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 112, 112, 64)      110656
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_19 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_20 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 224, 224, 64)      0
# _________________________________________________________________
# concatenate_5 (Concatenate)  (None, 224, 224, 96)      0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 224, 224, 32)      27680
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_21 (Activation)   (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 224, 224, 32)      9248
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_22 (Activation)   (None, 224, 224, 32)      0
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 224, 224, 1)       33
# _________________________________________________________________
# activation_23 (Activation)   (None, 224, 224, 1)       0
# =================================================================
# Total params: 31,466,753.0
# Trainable params: 31,454,721.0
# Non-trainable params: 12,032.0
# _________________________________________________________________

# %%
#Scored 0.290 with 100epochs without earlystopping and with cutoff labeling postprocess, dice as a measure
from keras.callbacks import EarlyStopping
epochs = 50

earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.zfunet_starter.hdf5', 
                               verbose=1, save_best_only=True)

zf_unet_starter.fit(train_files_tensors, train_target_tensors, validation_split=0.1,
          epochs=epochs, batch_size=20, callbacks=[earlystopper,checkpointer], verbose=1)
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
#  - ETA: 0s - loss: -0.6561 - dice_coef: 0.6561Epoch 00000: val_loss improved from inf to -0.00028, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 28s - loss: -0.6561 - dice_coef: 0.6561 - val_loss: -2.7642e-04 - val_dice_coef: 2.7642e-04
# Epoch 2/50
#  - ETA: 0s - loss: -0.8151 - dice_coef: 0.8151Epoch 00001: val_loss did not improve
#  - 17s - loss: -0.8149 - dice_coef: 0.8149 - val_loss: -9.7971e-06 - val_dice_coef: 9.7971e-06
# Epoch 3/50
#  - ETA: 0s - loss: -0.8524 - dice_coef: 0.8524Epoch 00002: val_loss improved from -0.00028 to -0.00589, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8511 - dice_coef: 0.8511 - val_loss: -0.0059 - val_dice_coef: 0.0059
# Epoch 4/50
#  - ETA: 0s - loss: -0.8095 - dice_coef: 0.8095Epoch 00003: val_loss improved from -0.00589 to -0.06344, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8078 - dice_coef: 0.8078 - val_loss: -0.0634 - val_dice_coef: 0.0634
# Epoch 5/50
#  - ETA: 0s - loss: -0.8649 - dice_coef: 0.8649Epoch 00004: val_loss improved from -0.06344 to -0.09680, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8641 - dice_coef: 0.8641 - val_loss: -0.0968 - val_dice_coef: 0.0968
# Epoch 6/50
#  - ETA: 0s - loss: -0.8684 - dice_coef: 0.8684Epoch 00005: val_loss improved from -0.09680 to -0.57914, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8686 - dice_coef: 0.8686 - val_loss: -0.5791 - val_dice_coef: 0.5791
# Epoch 7/50
#  - ETA: 0s - loss: -0.8800 - dice_coef: 0.8800Epoch 00006: val_loss improved from -0.57914 to -0.63192, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8795 - dice_coef: 0.8795 - val_loss: -0.6319 - val_dice_coef: 0.6319
# Epoch 8/50
#  - ETA: 0s - loss: -0.8800 - dice_coef: 0.8800Epoch 00007: val_loss did not improve
#  - 17s - loss: -0.8799 - dice_coef: 0.8799 - val_loss: -0.5828 - val_dice_coef: 0.5828
# Epoch 9/50
#  - ETA: 0s - loss: -0.8819 - dice_coef: 0.8819Epoch 00008: val_loss improved from -0.63192 to -0.76188, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8810 - dice_coef: 0.8810 - val_loss: -0.7619 - val_dice_coef: 0.7619
# Epoch 10/50
#  - ETA: 0s - loss: -0.8873 - dice_coef: 0.8873Epoch 00009: val_loss improved from -0.76188 to -0.87027, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8865 - dice_coef: 0.8865 - val_loss: -0.8703 - val_dice_coef: 0.8703
# Epoch 11/50
#  - ETA: 0s - loss: -0.8797 - dice_coef: 0.8797Epoch 00010: val_loss did not improve
#  - 17s - loss: -0.8799 - dice_coef: 0.8799 - val_loss: -0.6299 - val_dice_coef: 0.6299
# Epoch 12/50
#  - ETA: 0s - loss: -0.8923 - dice_coef: 0.8923Epoch 00011: val_loss did not improve
#  - 17s - loss: -0.8923 - dice_coef: 0.8923 - val_loss: -0.6395 - val_dice_coef: 0.6395
# Epoch 13/50
#  - ETA: 0s - loss: -0.8973 - dice_coef: 0.8973Epoch 00012: val_loss did not improve
#  - 17s - loss: -0.8966 - dice_coef: 0.8966 - val_loss: -0.8287 - val_dice_coef: 0.8287
# Epoch 14/50
#  - ETA: 0s - loss: -0.8762 - dice_coef: 0.8762Epoch 00013: val_loss did not improve
#  - 17s - loss: -0.8753 - dice_coef: 0.8753 - val_loss: -0.7407 - val_dice_coef: 0.7407
# Epoch 15/50
#  - ETA: 0s - loss: -0.8826 - dice_coef: 0.8826Epoch 00014: val_loss did not improve
#  - 17s - loss: -0.8829 - dice_coef: 0.8829 - val_loss: -0.8439 - val_dice_coef: 0.8439
# Epoch 16/50
#  - ETA: 0s - loss: -0.8949 - dice_coef: 0.8949Epoch 00015: val_loss improved from -0.87027 to -0.87153, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8950 - dice_coef: 0.8950 - val_loss: -0.8715 - val_dice_coef: 0.8715
# Epoch 17/50
#  - ETA: 0s - loss: -0.8953 - dice_coef: 0.8953Epoch 00016: val_loss did not improve
#  - 17s - loss: -0.8955 - dice_coef: 0.8955 - val_loss: -0.8680 - val_dice_coef: 0.8680
# Epoch 18/50
#  - ETA: 0s - loss: -0.8990 - dice_coef: 0.8990Epoch 00017: val_loss did not improve
#  - 17s - loss: -0.8992 - dice_coef: 0.8992 - val_loss: -0.8708 - val_dice_coef: 0.8708
# Epoch 19/50
#  - ETA: 0s - loss: -0.8999 - dice_coef: 0.8999Epoch 00018: val_loss improved from -0.87153 to -0.88453, saving model to saved_models/weights.best.zfunet_starter.hdf5
#  - 19s - loss: -0.8990 - dice_coef: 0.8990 - val_loss: -0.8845 - val_dice_coef: 0.8845
# Epoch 20/50
#  - ETA: 0s - loss: -0.8965 - dice_coef: 0.8965Epoch 00019: val_loss did not improve
#  - 17s - loss: -0.8953 - dice_coef: 0.8953 - val_loss: -0.4295 - val_dice_coef: 0.4295
# Epoch 21/50
#  - ETA: 0s - loss: -0.8641 - dice_coef: 0.8641Epoch 00020: val_loss did not improve
#  - 17s - loss: -0.8635 - dice_coef: 0.8635 - val_loss: -0.6031 - val_dice_coef: 0.6031
# Epoch 22/50
#  - ETA: 0s - loss: -0.8790 - dice_coef: 0.8790Epoch 00021: val_loss did not improve
#  - 17s - loss: -0.8790 - dice_coef: 0.8790 - val_loss: -0.7469 - val_dice_coef: 0.7469
# Epoch 23/50
#  - ETA: 0s - loss: -0.8912 - dice_coef: 0.8912Epoch 00022: val_loss did not improve
#  - 17s - loss: -0.8910 - dice_coef: 0.8910 - val_loss: -0.8559 - val_dice_coef: 0.8559
# Epoch 24/50
#  - ETA: 0s - loss: -0.8988 - dice_coef: 0.8988Epoch 00023: val_loss did not improve
#  - 17s - loss: -0.8989 - dice_coef: 0.8989 - val_loss: -0.8604 - val_dice_coef: 0.8604
# Epoch 25/50
#  - ETA: 0s - loss: -0.8965 - dice_coef: 0.8965Epoch 00024: val_loss did not improve
#  - 17s - loss: -0.8961 - dice_coef: 0.8961 - val_loss: -0.8667 - val_dice_coef: 0.8667
# Epoch 00024: early stopping

# %%
#Sanity Check:
predImage = detect_nuclei(zf_unet_starter,train_files[0])
plot_image(path_to_image(train_files[0]))
plot_image(train_targets_merged[0])
plot_image(predImage[0])
# Out:
# (224, 224, 3)
# (224, 224, 1)
# (224, 224, 1)

# %%
from keras.layers import Activation

base_model = ZF_UNET_224()
base_model.load_weights("saved_models/zf_unet_224.h5") # optional

#zf_unet_intermid = Model(inputs=base_model.input, outputs=top_model(base_model.output))
zf_unet_intermid = base_model

#slow leraning rate by a factor of 10
optim = Adam(lr=0.001/10)
zf_unet_intermid.summary()
zf_unet_intermid.compile(optimizer=optim , loss=[dice_coef_loss], metrics=[dice_coef])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_24 (Activation)   (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 224, 224, 32)      9248
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_25 (Activation)   (None, 224, 224, 32)      0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 112, 112, 64)      18496
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_26 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_27 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_28 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_29 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_30 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_31 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 14, 14, 512)       1180160
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_32 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_33 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 7, 7, 1024)        4719616
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 7, 7, 1024)        4096
# _________________________________________________________________
# activation_34 (Activation)   (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 7, 7, 1024)        9438208
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 7, 7, 1024)        4096
# _________________________________________________________________
# activation_35 (Activation)   (None, 7, 7, 1024)        0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 14, 14, 1024)      0
# _________________________________________________________________
# concatenate_6 (Concatenate)  (None, 14, 14, 1536)      0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 14, 14, 512)       7078400
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 28, 28, 512)       0
# _________________________________________________________________
# concatenate_7 (Concatenate)  (None, 28, 28, 768)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 28, 28, 256)       1769728
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_38 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_39 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 56, 56, 256)       0
# _________________________________________________________________
# concatenate_8 (Concatenate)  (None, 56, 56, 384)       0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 56, 56, 128)       442496
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_40 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_41 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 112, 112, 128)     0
# _________________________________________________________________
# concatenate_9 (Concatenate)  (None, 112, 112, 192)     0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 112, 112, 64)      110656
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_42 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_43 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 224, 224, 64)      0
# _________________________________________________________________
# concatenate_10 (Concatenate) (None, 224, 224, 96)      0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 224, 224, 32)      27680
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_44 (Activation)   (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 224, 224, 32)      9248
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_45 (Activation)   (None, 224, 224, 32)      0
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 224, 224, 1)       33
# _________________________________________________________________
# activation_46 (Activation)   (None, 224, 224, 1)       0
# =================================================================
# Total params: 31,466,753.0
# Trainable params: 31,454,721.0
# Non-trainable params: 12,032.0
# _________________________________________________________________

# %%
epochs = 50

earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.zfunet_intermid.hdf5', 
                               verbose=1, save_best_only=True)

zf_unet_intermid.fit(train_files_tensors, train_target_tensors, validation_split=0.1,
          epochs=epochs, batch_size=20, callbacks=[earlystopper,checkpointer], verbose=1)
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
#  - ETA: 0s - loss: -0.6722 - dice_coef: 0.6722Epoch 00000: val_loss improved from inf to -0.00754, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 25s - loss: -0.6717 - dice_coef: 0.6717 - val_loss: -0.0075 - val_dice_coef: 0.0075
# Epoch 2/50
#  - ETA: 0s - loss: -0.8124 - dice_coef: 0.8124Epoch 00001: val_loss improved from -0.00754 to -0.17103, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8124 - dice_coef: 0.8124 - val_loss: -0.1710 - val_dice_coef: 0.1710
# Epoch 3/50
#  - ETA: 0s - loss: -0.8441 - dice_coef: 0.8441Epoch 00002: val_loss improved from -0.17103 to -0.20555, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8427 - dice_coef: 0.8427 - val_loss: -0.2056 - val_dice_coef: 0.2056
# Epoch 4/50
#  - ETA: 0s - loss: -0.8602 - dice_coef: 0.8602Epoch 00003: val_loss improved from -0.20555 to -0.60751, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8581 - dice_coef: 0.8581 - val_loss: -0.6075 - val_dice_coef: 0.6075
# Epoch 5/50
#  - ETA: 0s - loss: -0.8460 - dice_coef: 0.8460Epoch 00004: val_loss did not improve
#  - 17s - loss: -0.8436 - dice_coef: 0.8436 - val_loss: -0.5167 - val_dice_coef: 0.5167
# Epoch 6/50
#  - ETA: 0s - loss: -0.8620 - dice_coef: 0.8620Epoch 00005: val_loss improved from -0.60751 to -0.75581, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8623 - dice_coef: 0.8623 - val_loss: -0.7558 - val_dice_coef: 0.7558
# Epoch 7/50
#  - ETA: 0s - loss: -0.8667 - dice_coef: 0.8667Epoch 00006: val_loss improved from -0.75581 to -0.83096, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 20s - loss: -0.8665 - dice_coef: 0.8665 - val_loss: -0.8310 - val_dice_coef: 0.8310
# Epoch 8/50
#  - ETA: 0s - loss: -0.8777 - dice_coef: 0.8777Epoch 00007: val_loss did not improve
#  - 17s - loss: -0.8777 - dice_coef: 0.8777 - val_loss: -0.7732 - val_dice_coef: 0.7732
# Epoch 9/50
#  - ETA: 0s - loss: -0.8869 - dice_coef: 0.8869Epoch 00008: val_loss improved from -0.83096 to -0.85049, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8867 - dice_coef: 0.8867 - val_loss: -0.8505 - val_dice_coef: 0.8505
# Epoch 10/50
#  - ETA: 0s - loss: -0.8892 - dice_coef: 0.8892Epoch 00009: val_loss improved from -0.85049 to -0.86070, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8892 - dice_coef: 0.8892 - val_loss: -0.8607 - val_dice_coef: 0.8607
# Epoch 11/50
#  - ETA: 0s - loss: -0.8902 - dice_coef: 0.8902Epoch 00010: val_loss improved from -0.86070 to -0.87780, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8903 - dice_coef: 0.8903 - val_loss: -0.8778 - val_dice_coef: 0.8778
# Epoch 12/50
#  - ETA: 0s - loss: -0.8922 - dice_coef: 0.8922Epoch 00011: val_loss did not improve
#  - 17s - loss: -0.8921 - dice_coef: 0.8921 - val_loss: -0.8755 - val_dice_coef: 0.8755
# Epoch 13/50
#  - ETA: 0s - loss: -0.8926 - dice_coef: 0.8926Epoch 00012: val_loss improved from -0.87780 to -0.88067, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8923 - dice_coef: 0.8923 - val_loss: -0.8807 - val_dice_coef: 0.8807
# Epoch 14/50
#  - ETA: 0s - loss: -0.8959 - dice_coef: 0.8959Epoch 00013: val_loss improved from -0.88067 to -0.88234, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8959 - dice_coef: 0.8959 - val_loss: -0.8823 - val_dice_coef: 0.8823
# Epoch 15/50
#  - ETA: 0s - loss: -0.8976 - dice_coef: 0.8976Epoch 00014: val_loss did not improve
#  - 17s - loss: -0.8961 - dice_coef: 0.8961 - val_loss: -0.8799 - val_dice_coef: 0.8799
# Epoch 16/50
#  - ETA: 0s - loss: -0.8925 - dice_coef: 0.8925Epoch 00015: val_loss did not improve
#  - 17s - loss: -0.8927 - dice_coef: 0.8927 - val_loss: -0.8619 - val_dice_coef: 0.8619
# Epoch 17/50
#  - ETA: 0s - loss: -0.8990 - dice_coef: 0.8990Epoch 00016: val_loss did not improve
#  - 17s - loss: -0.8987 - dice_coef: 0.8987 - val_loss: -0.8738 - val_dice_coef: 0.8738
# Epoch 18/50
#  - ETA: 0s - loss: -0.8976 - dice_coef: 0.8976Epoch 00017: val_loss did not improve
#  - 17s - loss: -0.8968 - dice_coef: 0.8968 - val_loss: -0.8710 - val_dice_coef: 0.8710
# Epoch 19/50
#  - ETA: 0s - loss: -0.8938 - dice_coef: 0.8938Epoch 00018: val_loss improved from -0.88234 to -0.88554, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8930 - dice_coef: 0.8930 - val_loss: -0.8855 - val_dice_coef: 0.8855
# Epoch 20/50
#  - ETA: 0s - loss: -0.8957 - dice_coef: 0.8957Epoch 00019: val_loss did not improve
#  - 17s - loss: -0.8957 - dice_coef: 0.8957 - val_loss: -0.8844 - val_dice_coef: 0.8844
# Epoch 21/50
#  - ETA: 0s - loss: -0.8922 - dice_coef: 0.8922Epoch 00020: val_loss did not improve
#  - 17s - loss: -0.8915 - dice_coef: 0.8915 - val_loss: -0.8412 - val_dice_coef: 0.8412
# Epoch 22/50
#  - ETA: 0s - loss: -0.8999 - dice_coef: 0.8999Epoch 00021: val_loss did not improve
#  - 17s - loss: -0.8996 - dice_coef: 0.8996 - val_loss: -0.8852 - val_dice_coef: 0.8852
# Epoch 23/50
#  - ETA: 0s - loss: -0.9007 - dice_coef: 0.9007Epoch 00022: val_loss improved from -0.88554 to -0.88668, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.9001 - dice_coef: 0.9001 - val_loss: -0.8867 - val_dice_coef: 0.8867
# Epoch 24/50
#  - ETA: 0s - loss: -0.8992 - dice_coef: 0.8992Epoch 00023: val_loss did not improve
#  - 17s - loss: -0.8988 - dice_coef: 0.8988 - val_loss: -0.8571 - val_dice_coef: 0.8571
# Epoch 25/50
#  - ETA: 0s - loss: -0.8964 - dice_coef: 0.8964Epoch 00024: val_loss did not improve
#  - 17s - loss: -0.8964 - dice_coef: 0.8964 - val_loss: -0.8817 - val_dice_coef: 0.8817
# Epoch 26/50
#  - ETA: 0s - loss: -0.8973 - dice_coef: 0.8973Epoch 00025: val_loss improved from -0.88668 to -0.88841, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.8970 - dice_coef: 0.8970 - val_loss: -0.8884 - val_dice_coef: 0.8884
# Epoch 27/50
#  - ETA: 0s - loss: -0.9002 - dice_coef: 0.9002Epoch 00026: val_loss did not improve
#  - 17s - loss: -0.8997 - dice_coef: 0.8997 - val_loss: -0.8848 - val_dice_coef: 0.8848
# Epoch 28/50
#  - ETA: 0s - loss: -0.9007 - dice_coef: 0.9007Epoch 00027: val_loss did not improve
#  - 17s - loss: -0.9006 - dice_coef: 0.9006 - val_loss: -0.8859 - val_dice_coef: 0.8859
# Epoch 29/50
#  - ETA: 0s - loss: -0.9027 - dice_coef: 0.9027Epoch 00028: val_loss did not improve
#  - 17s - loss: -0.9016 - dice_coef: 0.9016 - val_loss: -0.8809 - val_dice_coef: 0.8809
# Epoch 30/50
#  - ETA: 0s - loss: -0.9032 - dice_coef: 0.9032Epoch 00029: val_loss did not improve
#  - 17s - loss: -0.9016 - dice_coef: 0.9016 - val_loss: -0.8873 - val_dice_coef: 0.8873
# Epoch 31/50
#  - ETA: 0s - loss: -0.9024 - dice_coef: 0.9024Epoch 00030: val_loss did not improve
#  - 17s - loss: -0.9026 - dice_coef: 0.9026 - val_loss: -0.8876 - val_dice_coef: 0.8876
# Epoch 32/50
#  - ETA: 0s - loss: -0.9056 - dice_coef: 0.9056Epoch 00031: val_loss improved from -0.88841 to -0.89064, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 20s - loss: -0.9054 - dice_coef: 0.9054 - val_loss: -0.8906 - val_dice_coef: 0.8906
# Epoch 33/50
#  - ETA: 0s - loss: -0.9064 - dice_coef: 0.9064Epoch 00032: val_loss improved from -0.89064 to -0.89381, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.9063 - dice_coef: 0.9063 - val_loss: -0.8938 - val_dice_coef: 0.8938
# Epoch 34/50
#  - ETA: 0s - loss: -0.9049 - dice_coef: 0.9049Epoch 00033: val_loss did not improve
#  - 17s - loss: -0.9051 - dice_coef: 0.9051 - val_loss: -0.8929 - val_dice_coef: 0.8929
# Epoch 35/50
#  - ETA: 0s - loss: -0.9079 - dice_coef: 0.9079Epoch 00034: val_loss did not improve
#  - 17s - loss: -0.9079 - dice_coef: 0.9079 - val_loss: -0.8887 - val_dice_coef: 0.8887
# Epoch 36/50
#  - ETA: 0s - loss: -0.9102 - dice_coef: 0.9102Epoch 00035: val_loss improved from -0.89381 to -0.89502, saving model to saved_models/weights.best.zfunet_intermid.hdf5
#  - 19s - loss: -0.9100 - dice_coef: 0.9100 - val_loss: -0.8950 - val_dice_coef: 0.8950
# Epoch 37/50
#  - ETA: 0s - loss: -0.9094 - dice_coef: 0.9094Epoch 00036: val_loss did not improve
#  - 17s - loss: -0.9096 - dice_coef: 0.9096 - val_loss: -0.8939 - val_dice_coef: 0.8939
# Epoch 38/50
#  - ETA: 0s - loss: -0.9104 - dice_coef: 0.9104Epoch 00037: val_loss did not improve
#  - 17s - loss: -0.9103 - dice_coef: 0.9103 - val_loss: -0.8874 - val_dice_coef: 0.8874
# Epoch 39/50
#  - ETA: 0s - loss: -0.9064 - dice_coef: 0.9064Epoch 00038: val_loss did not improve
#  - 17s - loss: -0.9065 - dice_coef: 0.9065 - val_loss: -0.8846 - val_dice_coef: 0.8846
# Epoch 40/50
#  - ETA: 0s - loss: -0.9110 - dice_coef: 0.9110Epoch 00039: val_loss did not improve
#  - 17s - loss: -0.9110 - dice_coef: 0.9110 - val_loss: -0.8912 - val_dice_coef: 0.8912
# Epoch 41/50
#  - ETA: 0s - loss: -0.9107 - dice_coef: 0.9107Epoch 00040: val_loss did not improve
#  - 17s - loss: -0.9106 - dice_coef: 0.9106 - val_loss: -0.8950 - val_dice_coef: 0.8950
# Epoch 42/50
#  - ETA: 0s - loss: -0.9094 - dice_coef: 0.9094Epoch 00041: val_loss did not improve
#  - 17s - loss: -0.9095 - dice_coef: 0.9095 - val_loss: -0.8825 - val_dice_coef: 0.8825
# Epoch 00041: early stopping

# %%
#Read Test Data:
def load_testset(path):
    nuclei_files = np.array(glob(path+'/*/images/*'))
    return nuclei_files

def get_image_resolution(img_path):
    image = io.imread(img_path)
    return image.shape[:2]

def get_img_list_dims(test_files):
    dims_tuples = []
    for path in test_files:
        dims_tuples.append(get_image_resolution(path))
    return dims_tuples

def resize_image(image_as_array, desired_size_tuple):
    image_resized = np.squeeze(resize(image_as_array, desired_size_tuple, mode='constant'))
    #plot_image(image_resized)
    return image_resized


def get_predections(test_dataset_paths,predection_model):
    original_dims = get_img_list_dims(test_dataset_paths)
    test_predections_rescaled = []
    print("Predicting test images")
    for i,img_path in enumerate(tqdm(test_dataset_paths)):
        tensor = predection_model.predict(path_to_tensor(img_path))
        image = tensor[0]
        resized_image = resize_image(image,original_dims[i])
        #print(resized_image.shape)
        test_predections_rescaled.append(resized_image)
    print("Finished perdicting test images")
    return test_predections_rescaled

# %%
TEST_PATH='stage1_test/'           
test_files = load_dataset(TEST_PATH)[0]
predection_images_resized = get_predections(test_files,zf_unet_intermid)
# Out:
# Predicting test images
# 100%|███████████████████████████████████████████████████████████████████████████████| 65/65 [00:03<00:00, 19.65it/s]
# Finished perdicting test images

# %%
#TODO fix IOU
#Inspired from https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277#295658 and https://www.kaggle.com/wcukierski/example-metric-implementation


def meanIoU(y_true_batch, y_pred_batch):
    return np.mean(np.asarray([IoU(y_pred_batch, y_true_batch,thresholds) for thresholds in np.arange(0.5, 1, 0.05)])) 

def IoU(y_pred_batch, y_true_batch, threshold):
    pxArray = []
    for i in range(y_true_batch):
        print(i)
        px = pixelAccuracy(y_pred_batch[i], y_true_batch[i],threshold)
        pxArray.append(px)
    
    return pxArray

# http://scikit-image.org/docs/dev/auto_examples/segmentation/plot_join_segmentations.html
def pixelAccuracy(y_pred_orig, y_true, threshold):
    print(y_pred_orig, y_true, threshold)
    y_pred = wrap_booleans(y_pred_orig > threshold)
    #true positive / (true positive + false positive + false negative)
    tp/tp+fp+fn
    return np.sum(wrap_booleans()*wrap_booleans(y_true>0)) /  (np.sum(wrap_booleans(y_pred>0)) + np.sum(wrap_booleans(y_true>0)) - np.sum(wrap_booleans(y_pred==y_true))*wrap_booleans(y_true>0))

def wrap_booleans (exp):
    if exp: return 1
    else: return 0

# %%
#TODO RLE
from skimage.morphology import label
from skimage.segmentation import watershed, random_walker
from scipy import ndimage
from skimage.feature import peak_local_max

# Run-length encoding from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

#Taken from https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277?scriptVersionId=2164855
def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    #print(lab_img)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

#Experminations with watershed and random walker 
#Source: (http://www.scipy-lectures.org/packages/scikit-image/auto_examples/plot_segmentations.html)
def label_rw_to_rles(image):
    distance = ndimage.distance_transform_edt(image)
    local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=image)
    markers = label(local_maxi)
    markers[~image] = -1 #TODO fix
    labels_rw = random_walker(image, markers)
    for i in range(1, labels_rw.max() + 1):
        yield rle_encoding(labels_rw == i)
    
def label_ws_to_rles(image):
    distance = ndimage.distance_transform_edt(image)
    local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=image)
    markers = label(local_maxi)
    labels_ws = watershed(-distance, markers, mask=image)
    for i in range(1, labels_ws.max() + 1):
        yield rle_encoding(labels_ws == i)

# %%
#Taken from https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277?scriptVersionId=2164855

test_ids = next(os.walk(TEST_PATH))[1]
new_test_ids = []
rles = []
#print(predection_images_resized)
for n, id_ in enumerate(tqdm(test_ids)):
    rle = list(prob_to_rles(predection_images_resized[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

#print(rles)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 65/65 [00:01<00:00, 50.02it/s]

# %%
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %%
#Experminations with ws 

rn = random.randint(0, len(predection_images_resized))
print(rn)
pred_image = predection_images_resized[rn]

plt.imshow(pred_image, cmap='spectral', interpolation='nearest')
plt.axis('off')
plt.title('actual image')
plt.show()


lab_img = label(pred_image >0.5)
plt.imshow(lab_img, cmap='spectral', interpolation='nearest')
plt.axis('off')
plt.title('label segmentation')
plt.show()



distance = ndimage.distance_transform_edt(pred_image)
local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=pred_image)
markers = label(local_maxi)
labels_ws = watershed(-distance, markers, mask=pred_image)


plt.imshow(labels_ws, cmap='spectral', interpolation='nearest')
plt.axis('off')
plt.title('watershed segmentation')
plt.show()
# Out:
# 44
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-8ebf411fcdd5> in <module>()
#      20
#      21 distance = ndimage.distance_transform_edt(pred_image)
# ---> 22 local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=pred_image)
#      23 markers = label(local_maxi)
#      24 labels_ws = watershed(-distance, markers, mask=pred_image)
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\skimage\feature\peak.py in peak_local_max(image, min_distance, threshold_abs, threshold_rel, exclude_border, indices, num_peaks, footprint, labels, num_peaks_per_label)
#     127         if np.any(np.diff(label_values) != 1):
#     128             mask = labels >= 1
# --> 129             labels[mask] = 1 + rank_order(labels[mask])[0].astype(labels.dtype)
#     130         labels = labels.astype(np.int32)
#     131
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\skimage\filters\_rank_order.py in rank_order(image)
#      53     is_different = flat_image[:-1] != flat_image[1:]
#      54     np.cumsum(is_different, out=sort_rank[1:])
# ---> 55     original_values = np.zeros((sort_rank[-1] + 1,), image.dtype)
#      56     original_values[0] = flat_image[0]
#      57     original_values[1:] = flat_image[1:][is_different]
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
#Double U-Net? Freeze, Xception as Encoder Reverse Xception as Decoder

# %% [markdown]
# ## **II. Analysis**
#
# *(approx. 2-4 pages)*
#
# ### **Data Exploration**
#
# In this section, you will be expected to analyze the data you are using for the problem. This data can either be in the form of a dataset (or datasets), input data (or input files), or even an environment. The type of data should be thoroughly described and, if possible, have basic statistics and information presented (such as discussion of input features or defining characteristics about the input or environment). Any abnormalities or interesting qualities about the data that may need to be addressed have been identified (such as features that need to be transformed or the possibility of outliers). Questions to ask yourself when writing this section:
#
# * *If a dataset is present for this problem, have you thoroughly discussed certain features about the dataset? Has a data sample been provided to the reader?*
#
# * *If a dataset is present for this problem, are statistics about the dataset calculated and reported? Have any relevant results from this calculation been discussed?*
#
# * *If a dataset is not present for this problem, has discussion been made about the input space or input data for your problem?*
#
# * *Are there any abnormalities or characteristics about the input space or dataset that need to be addressed? (categorical variables, missing values, outliers, etc.)*

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    nuclei_files = np.array(glob(path+'/*/images/*'))
    nuclei_targets = np.array(glob(path+'/*/masks/*'))
    return nuclei_files,nuclei_targets

    
def load_dataset_2(path):
    training_paths = pathlib.Path(path).glob('*/images/*.png')
    training_sorted = sorted([x for x in training_paths])
    im_path = training_sorted[45]
    im = imageio.imread(str(im_path))
    #nuclei_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return nuclei_files#, nuclei_target

train_files,train_targets = load_dataset('stage1_train/')
test_files,test_targets= load_dataset('stage1_test/')

#TODO: pick a better represntation of a validation set


print('There are %d training batch nuecli images.' % len(train_files))
print('There are %d training batch nuecli masks.' % len(train_targets))
# Out:
# There are 670 training batch nuecli images.
# There are 29461 training batch nuecli masks.

# %%
# Binding masks with the parent image:
import os.path

def get_filename(path):
    return os.path.splitext(os.path.basename(path))[0]

def bind_mask_to_images(images_paths, masks_paths):
    image_id = 0
    filename = get_filename(images_paths[0])
    masks_binded = [[]]
    for mask_path in masks_paths:
        if filename in mask_path:
            masks_binded[image_id].append(mask_path)
        else:
            image_id = image_id+1
            filename = get_filename(images_paths[image_id])
            masks_binded.append([mask_path])
    return np.array(masks_binded)

    
train_targets_binded = bind_mask_to_images(train_files,train_targets)
#train_targets_merged = merge_masks(train_targets_binded)

print("Train targets have been binded")
# Out:
# Train targets have been binded

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# load color (BGR) image
img = cv2.imread(train_files[3])
# convert BGR image to grayscale
gray = cv2.imread(train_files[3],0)


#from skimage.color import rgb2gray
#im_gray = rgb2gray(img)

plt.subplot(1,2,1)
plt.imshow(img)
plt.title("Original image")
plt.subplot(1,2,2)
plt.title("Greyscaled image")
plt.imshow(gray)
plt.show()
#pixel intensity for image
plt.hist(gray.ravel(),256,[0,256])
plt.title("Pixel intensity of the image")
plt.show()

# %% [markdown]
# ### Sources:
# - https://docs.opencv.org/3.1.0/d1/db7/tutorial_py_histogram_begins.html
# - https://www.pyimagesearch.com/2014/05/26/opencv-python-k-means-color-clustering/
# - dog-project

# %%
from sklearn.cluster import KMeans
import random

seed = random.seed(8675309)
def find_dominant_color_in_image(image,number_of_clusters):
    # re-shape our image to be a list of pixels, rather than MxN matrix of pixels
    image = image.reshape((image.shape[0] * image.shape[1], 3))
    color_clf = KMeans(random_state=seed,n_clusters = number_of_clusters)
    color_clf.fit(image)
    
    return color_clf.cluster_centers_

def cluster_images_based_on_color(images_path_array,number_of_clusters,number_of_colors):
    dominant_colors = []
    for image_path in images_path_array:
        image = cv2.imread(image_path)
        colors_in_image = find_dominant_color_in_image(image,number_of_colors)
        dominant_colors.append(colors_in_image.flatten())
    #print(image)
    #print(dominant_colors)
    img_clf = KMeans(random_state=seed,n_clusters = number_of_clusters)
    img_clf.fit(np.array(dominant_colors))
    return img_clf

def plot_color_bar(colors):
    bar = np.zeros((50, 300, 3), dtype = "uint8")
    startX = 0
    for color in colors:
        #print ("color in bar",color)
        endX = startX + (1/len(colors) * 300)
        #print("the start is",startX, 'the end is',endX)
        cv2.rectangle(bar, (int(startX), 0), (int(endX), 50),color.astype("uint8").tolist(), -1)
        startX = endX
    plt.figure()
    plt.axis("off")
    plt.imshow(bar)
    plt.show()
    return bar

# %%
number_of_colors = 3
images_clf = cluster_images_based_on_color(train_files,3,number_of_colors)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bcbced63e801> in <module>()
#       1 number_of_colors = 3
# ----> 2 images_clf = cluster_images_based_on_color(train_files,3,number_of_colors)
#
# <ipython-input-9-f22762bd2c95> in cluster_images_based_on_color(images_path_array, number_of_clusters, number_of_colors)
#      15     for image_path in images_path_array:
#      16         image = cv2.imread(image_path)
# ---> 17         colors_in_image = find_dominant_color_in_image(image,number_of_colors)
#      18         dominant_colors.append(colors_in_image.flatten())
#      19     #print(image)
#
# <ipython-input-9-f22762bd2c95> in find_dominant_color_in_image(image, number_of_clusters)
#       7     image = image.reshape((image.shape[0] * image.shape[1], 3))
#       8     color_clf = KMeans(random_state=seed,n_clusters = number_of_clusters)
# ----> 9     color_clf.fit(image)
#      10
#      11     return color_clf.cluster_centers_
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y)
#     887                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     888                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 889                 return_n_iter=True)
#     890         return self
#     891
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     343                 X, n_clusters, max_iter=max_iter, init=init, verbose=verbose,
#     344                 precompute_distances=precompute_distances, tol=tol,
# --> 345                 x_squared_norms=x_squared_norms, random_state=random_state)
#     346             # determine if these results are the best so far
#     347             if best_inertia is None or inertia < best_inertia:
#
# D:\Kareem\Conda\envs\dog-project\lib\site-packages\sklearn\cluster\k_means_.py in _kmeans_single_elkan(X, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     398     centers, labels, n_iter = k_means_elkan(X, n_clusters, centers, tol=tol,
#     399                                             max_iter=max_iter, verbose=verbose)
# --> 400     inertia = np.sum((X - centers[labels]) ** 2, dtype=np.float64)
#     401     return labels, inertia, centers, n_iter
#     402
#
# KeyboardInterrupt:

# %%
colors_clusters = images_clf.cluster_centers_
labels = images_clf.labels_
print(len(labels))
RGB_COLORS_CONSTANT = 3
if(number_of_colors>1):
    for color in colors_clusters:
        plot_color_bar(np.split(color,RGB_COLORS_CONSTANT))
else:
    for color in colors_clusters:
        plot_color_bar(color)

# %% [markdown]
# ## Colors and Stains:
#
# We can observe from the previous clusters that the dataset is stained differently, the differences in coloring. Hence, we'll be using grayscale?

# %%
#print (images_clf)
sample_image = cv2.imread(train_files[0])
#print (sample_image.shape[1])
def get_images_features_list(images_path_array):
    images_height = []
    images_width = []
    images_mean = []
    images_std= []
    for image_path in images_path_array:
        image = cv2.imread(image_path)
        images_height.append(image.shape[0])
        images_width.append(image.shape[1])
        images_mean.append(np.mean(image))
        images_std.append(np.std(image))
    return images_height,images_width,images_mean,images_std

def plot_scatter_plot(X,y):
    plt.xlabel("Height (px)")
    plt.ylabel("Width (px)")
    plt.title("Resolution Scatter Plot")
    plt.scatter(X, y)
    
X,y,means,stdvs = get_images_features_list(train_files)
plot_scatter_plot(X,y)

# %%
heatmap, xedges, yedges = np.histogram2d(X, y, bins=10)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.imshow(heatmap.T, extent=extent, origin='lower')
plt.show()

paired = (list(zip(X,y)))

# %%
import pandas as pd
import seaborn as sns

df = pd.DataFrame(data=paired)
#print(df.keys)
df.index.name = 'x label'

ax = df.plot.hexbin(x=0, y=1, gridsize=5,title="Resolution Heatmap",)
ax.set_ylabel("Width (px)")
ax.set_xlabel("Height (px)") #bug in juypter notebook doens't show the x-axis

# %%
#Plot "Pixel Intensity Means for All Images" and "Standard Deviation per Image"

plt.plot(means, np.zeros_like(means), 'x')
plt.xlabel("Image mean (px)")
plt.title("Pixel Intensity Means for All Images")
plt.axes().get_yaxis().set_visible(False)
plt.show()
plt.plot(stdvs, np.zeros_like(stdvs), 'r+')
plt.title("Images Standard Deviation")
plt.axes().get_yaxis().set_visible(False)
plt.xlabel("Standard Deviation per Image (px)")
plt.show()

# %% [markdown]
# ## Preprocessing:

# %%
#Taken from dog-project, Preprocessing for Keras
from keras.preprocessing import image as KImage                  
from tqdm import tqdm
from PIL import ImageFile                            
from skimage import io, img_as_float
from skimage.transform import resize
from skimage.color import rgb2gray,rgba2rgb

img_height, img_width = 150,150

#Doesn't work shows target fully black.
def old_path_to_image(img_path):
    # loads RGB image as PIL.Image.Image type
    #image = io.imread(img_path)
    #image = img_as_float(image)
    #print(img_path)
    img = KImage.load_img(img_path, target_size=(img_height, img_width))
    # convert PIL.Image.Image type to 3D tensor with shape (150, 150, 3)
    image_array = KImage.img_to_array(img)
    return image_array

def path_to_image(img_path):
    image = io.imread(img_path)
    #transform image to (150,150)
    image = resize(image, (img_height, img_width), mode='constant')
    #rgba to rgb
    try:
        image = rgba2rgb(image)
    except:
        image = np.expand_dims(image,axis=-1)
    image = img_as_float(image)
    return image

def path_to_tensor(img_path):
    x = path_to_image(img_path)
    return image_to_tensor(x)

def image_to_tensor(img):
    # convert 3D tensor to 4D tensor with shape (1, 150, 150, 3) and return 4D tensor
    return np.expand_dims(img, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    #print(list_of_tensors[0])
    return np.vstack(list_of_tensors)

def images_to_tensor(img_list):
    list_of_tensors = [image_to_tensor(img_list) for img_list in tqdm(img_list)]
    #print(list_of_tensors[0])
    return np.vstack(list_of_tensors)

# %%
def merge_masks(train_targets_binded):
    bigboy = []
    for binder in (train_targets_binded):
        merged_mask = np.zeros_like(path_to_image(binder[0]))##.astype('float32')/255 ?
        for mask_path in binder:
            mask = path_to_image(mask_path)
            merged_mask = np.maximum(merged_mask,mask)
        binder = merged_mask
        bigboy.append(merged_mask)
    return bigboy

# %%
#ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras, since we need to match the pre-trained enviroment
train_files_tensors = paths_to_tensor(train_files)

train_targets_merged = merge_masks(train_targets_binded)
#print(train_targets_merged[0])
train_target_tensors = images_to_tensor(train_targets_merged)

print(train_files.shape)
print(train_targets_binded.shape)
#print(train_targets_merged.shape)
print(train_files_tensors.shape)
print(train_target_tensors.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 670/670 [00:08<00:00, 77.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 670/670 [00:00<00:00, 667819.32it/s]
# (670,)
# (670,)
# (670, 150, 150, 3)
# (670, 150, 150, 1)

# %% [markdown]
# ### Sanity Check:

# %%
def plot_image(img):
    print(img.shape)
    plt.imshow(np.squeeze(img))
    #print(img)
    plt.show()
    
plot_image(train_files_tensors[1])
plot_image(train_target_tensors[1])
s = path_to_image(train_files[1])
#s = np.expand_dims(train_files_tensors[1], axis=-1)
plot_image(s)
print(range(train_files_tensors.shape[:1][0]-1))
# Out:
# (150, 150, 3)
# (150, 150, 1)
# (150, 150, 3)
# range(0, 669)

# %% [markdown]
# ### Model:

# %%
from keras.applications.xception import Xception, preprocess_input
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Conv2DTranspose
from keras.layers import Dropout, Flatten, Dense, Reshape
from keras.models import Sequential,Model

#TODO bottleneck_features
base_model = Xception(input_shape=train_files_tensors.shape[1:],weights='imagenet', include_top=False)

xc = base_model.output

# %%
from keras.layers import Conv2DTranspose
from keras.layers.merge import concatenate

xc = base_model.output

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (xc)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

c10 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)
c10 = Dropout(0.1) (c10)
c10 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c10)
p10 = MaxPooling2D(pool_size=(2, 2)) (c10)

c11 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p10)
c11 = Dropout(0.1) (c11)
c11 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c11)
p11 = MaxPooling2D(pool_size=(2, 2)) (c11)




output = Conv2D(1, (1, 1), activation='sigmoid') (p11)

#output= Conv2DTranspose(3, (3, 3), strides=(30, 30), padding='same',activation='relu')(xc)
#ct1 = Conv2DTranspose(729, (2, 2), strides=(2, 2), padding='same',activation='relu')(xc)
#ct2 = Conv2DTranspose(81, (2, 2), strides=(3, 3), padding='same',activation='relu')(ct1)
#output = Conv2DTranspose(3, (2, 2), strides=(5, 5), padding='same',activation='relu')(ct2)
# add your top layer block to your base model
Xception_starter_model = Model(base_model.input, output)

# freeze Xception layers
for layer in Xception_starter_model.layers[:132]:
    layer.trainable = False

print(Xception_starter_model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_4 (InputLayer)             (None, 150, 150, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, 74, 74, 32)    864
# ____________________________________________________________________________________________________
# block1_conv1_bn (BatchNormalizat (None, 74, 74, 32)    128
# ____________________________________________________________________________________________________
# block1_conv1_act (Activation)    (None, 74, 74, 32)    0
# ____________________________________________________________________________________________________
# block1_conv2 (Conv2D)            (None, 72, 72, 64)    18432
# ____________________________________________________________________________________________________
# block1_conv2_bn (BatchNormalizat (None, 72, 72, 64)    256
# ____________________________________________________________________________________________________
# block1_conv2_act (Activation)    (None, 72, 72, 64)    0
# ____________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2D (None, 72, 72, 128)   8768
# ____________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormali (None, 72, 72, 128)   512
# ____________________________________________________________________________________________________
# block2_sepconv2_act (Activation) (None, 72, 72, 128)   0
# ____________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2D (None, 72, 72, 128)   17536
# ____________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormali (None, 72, 72, 128)   512
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 36, 36, 128)   8192
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 36, 36, 128)   0
# ____________________________________________________________________________________________________
# batch_normalization_13 (BatchNor (None, 36, 36, 128)   512
# ____________________________________________________________________________________________________
# add_37 (Add)                     (None, 36, 36, 128)   0
# ____________________________________________________________________________________________________
# block3_sepconv1_act (Activation) (None, 36, 36, 128)   0
# ____________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2D (None, 36, 36, 256)   33920
# ____________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormali (None, 36, 36, 256)   1024
# ____________________________________________________________________________________________________
# block3_sepconv2_act (Activation) (None, 36, 36, 256)   0
# ____________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2D (None, 36, 36, 256)   67840
# ____________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormali (None, 36, 36, 256)   1024
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 18, 18, 256)   32768
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 18, 18, 256)   0
# ____________________________________________________________________________________________________
# batch_normalization_14 (BatchNor (None, 18, 18, 256)   1024
# ____________________________________________________________________________________________________
# add_38 (Add)                     (None, 18, 18, 256)   0
# ____________________________________________________________________________________________________
# block4_sepconv1_act (Activation) (None, 18, 18, 256)   0
# ____________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2D (None, 18, 18, 728)   188672
# ____________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormali (None, 18, 18, 728)   2912
# ____________________________________________________________________________________________________
# block4_sepconv2_act (Activation) (None, 18, 18, 728)   0
# ____________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2D (None, 18, 18, 728)   536536
# ____________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormali (None, 18, 18, 728)   2912
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 9, 9, 728)     186368
# ____________________________________________________________________________________________________
# block4_pool (MaxPooling2D)       (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# batch_normalization_15 (BatchNor (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_39 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block5_sepconv1_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block5_sepconv2_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block5_sepconv3_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_40 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block6_sepconv1_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block6_sepconv2_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block6_sepconv3_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_41 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block7_sepconv1_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block7_sepconv2_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block7_sepconv3_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_42 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block8_sepconv1_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block8_sepconv2_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block8_sepconv3_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_43 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block9_sepconv1_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block9_sepconv2_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block9_sepconv3_act (Activation) (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2D (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormali (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_44 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block10_sepconv1_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block10_sepconv2_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block10_sepconv3_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_45 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block11_sepconv1_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block11_sepconv2_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block11_sepconv3_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_46 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block12_sepconv1_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block12_sepconv2_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block12_sepconv3_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# add_47 (Add)                     (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block13_sepconv1_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv2 (None, 9, 9, 728)     536536
# ____________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNormal (None, 9, 9, 728)     2912
# ____________________________________________________________________________________________________
# block13_sepconv2_act (Activation (None, 9, 9, 728)     0
# ____________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv2 (None, 9, 9, 1024)    752024
# ____________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNormal (None, 9, 9, 1024)    4096
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 5, 5, 1024)    745472
# ____________________________________________________________________________________________________
# block13_pool (MaxPooling2D)      (None, 5, 5, 1024)    0
# ____________________________________________________________________________________________________
# batch_normalization_16 (BatchNor (None, 5, 5, 1024)    4096
# ____________________________________________________________________________________________________
# add_48 (Add)                     (None, 5, 5, 1024)    0
# ____________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv2 (None, 5, 5, 1536)    1582080
# ____________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNormal (None, 5, 5, 1536)    6144
# ____________________________________________________________________________________________________
# block14_sepconv1_act (Activation (None, 5, 5, 1536)    0
# ____________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv2 (None, 5, 5, 2048)    3159552
# ____________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNormal (None, 5, 5, 2048)    8192
# ____________________________________________________________________________________________________
# block14_sepconv2_act (Activation (None, 5, 5, 2048)    0
# ____________________________________________________________________________________________________
# conv2d_transpose_181 (Conv2DTran (None, 10, 10, 128)   1048704
# ____________________________________________________________________________________________________
# conv2d_256 (Conv2D)              (None, 10, 10, 128)   147584
# ____________________________________________________________________________________________________
# dropout_115 (Dropout)            (None, 10, 10, 128)   0
# ____________________________________________________________________________________________________
# conv2d_257 (Conv2D)              (None, 10, 10, 128)   147584
# ____________________________________________________________________________________________________
# conv2d_transpose_182 (Conv2DTran (None, 20, 20, 64)    32832
# ____________________________________________________________________________________________________
# conv2d_258 (Conv2D)              (None, 20, 20, 64)    36928
# ____________________________________________________________________________________________________
# dropout_116 (Dropout)            (None, 20, 20, 64)    0
# ____________________________________________________________________________________________________
# conv2d_259 (Conv2D)              (None, 20, 20, 64)    36928
# ____________________________________________________________________________________________________
# conv2d_transpose_183 (Conv2DTran (None, 40, 40, 32)    8224
# ____________________________________________________________________________________________________
# conv2d_260 (Conv2D)              (None, 40, 40, 32)    9248
# ____________________________________________________________________________________________________
# dropout_117 (Dropout)            (None, 40, 40, 32)    0
# ____________________________________________________________________________________________________
# conv2d_261 (Conv2D)              (None, 40, 40, 32)    9248
# ____________________________________________________________________________________________________
# conv2d_transpose_184 (Conv2DTran (None, 80, 80, 16)    2064
# ____________________________________________________________________________________________________
# conv2d_262 (Conv2D)              (None, 80, 80, 16)    2320
# ____________________________________________________________________________________________________
# dropout_118 (Dropout)            (None, 80, 80, 16)    0
# ____________________________________________________________________________________________________
# conv2d_263 (Conv2D)              (None, 80, 80, 16)    2320
# ____________________________________________________________________________________________________
# conv2d_264 (Conv2D)              (None, 80, 80, 32)    4640
# ____________________________________________________________________________________________________
# dropout_119 (Dropout)            (None, 80, 80, 32)    0
# ____________________________________________________________________________________________________
# conv2d_265 (Conv2D)              (None, 80, 80, 32)    9248
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)   (None, 40, 40, 32)    0
# ____________________________________________________________________________________________________
# conv2d_266 (Conv2D)              (None, 40, 40, 32)    9248
# ____________________________________________________________________________________________________
# dropout_120 (Dropout)            (None, 40, 40, 32)    0
# ____________________________________________________________________________________________________
# conv2d_267 (Conv2D)              (None, 40, 40, 32)    9248
# ____________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)   (None, 20, 20, 32)    0
# ____________________________________________________________________________________________________
# conv2d_268 (Conv2D)              (None, 20, 20, 1)     33
# ====================================================================================================
# Total params: 22,377,881.0
# Trainable params: 1,516,401.0
# Non-trainable params: 20,861,480.0
# ____________________________________________________________________________________________________
# None

# %%
#RESET

# %%
xc = base_model.output

ct1 = Conv2DTranspose(729, (2, 2), strides=(2, 2), padding='same',activation='relu')(xc)
c6 = Conv2D(729, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(ct1)
c6 = Dropout(0.2)(c6)
c6 = Conv2D(729, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c6)
ct2 = Conv2DTranspose(81, (2, 2), strides=(3, 3), padding='same',activation='relu')(c6)
c7 = Conv2D(81, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(ct2)
c7 = Dropout(0.2)(c7)
c7 = Conv2D(81, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c7)
output = Conv2DTranspose(3, (2, 2), strides=(5, 5), padding='same',activation='relu')(c7)

Xception_intermid_model = Model(base_model.input, output)

# freeze Xception layers
for layer in Xception_intermid_model.layers[:132]:
    layer.trainable = False

print(Xception_intermid_model.summary())

# %% [markdown]
# ### Metric:

# %%
#Taken from https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277#295658

def meanIoU(y_true_batch, y_pred_batch):
    return np.mean(np.asarray([IoU(y_pred_batch, y_true_batch,t) for t in np.arange(0.5, 1, 0.05)])) 

def IoU(y_pred_batch, y_true_batch, threshold):
    pxArray = []
    print(y_true_batch[0])
    plot_image(y_true_batch[0])
    print(y_pred_batch[0])
    print(threshold)
    
    for i in range(y_true_batch.shape[:1][0]):
        print(y_true_batch[i])
        print(y_pred_batch[i])
        px = pixelAccuracy(y_pred_batch[i], y_true_batch[i],threshold)
        pxArray.append(px)
    
    return 0

def pixelAccuracy(y_pred_orig, y_true, threshold):
    y_pred = (y_pred_orig > threshold)   
    return 1.0 * np.sum((y_pred==y_true)*(y_true>0)) /  (np.sum(y_pred>0) + np.sum(y_true>0) - np.sum((y_pred==y_true)*(y_true>0)))

# %%
# Metric function
from keras import backend as K
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Loss funtion
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# ### Compile:

# %%
Xception_starter_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=[dice_coef])

# %%
# taken from dog-project
from keras.callbacks import ModelCheckpoint  

epochs = 50

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.xception_interim.hdf5', 
                               verbose=1, save_best_only=True)

Xception_starter_model.fit(train_files_tensors, train_files_tensors, validation_split=0.1,
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
#  - ETA: 0s - loss: 0.4648 - dice_coef: 0.1783Epoch 00000: val_loss improved from inf to 0.38735, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 5s - loss: 0.4642 - dice_coef: 0.1780 - val_loss: 0.3874 - val_dice_coef: 0.1468
# Epoch 2/50
#  - ETA: 0s - loss: 0.4650 - dice_coef: 0.1792Epoch 00001: val_loss improved from 0.38735 to 0.38608, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 5s - loss: 0.4642 - dice_coef: 0.1788 - val_loss: 0.3861 - val_dice_coef: 0.1458
# Epoch 3/50
#  - ETA: 0s - loss: 0.4655 - dice_coef: 0.1766Epoch 00002: val_loss improved from 0.38608 to 0.38478, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 5s - loss: 0.4644 - dice_coef: 0.1760 - val_loss: 0.3848 - val_dice_coef: 0.1446
# Epoch 4/50
#  - ETA: 0s - loss: 0.4652 - dice_coef: 0.1769Epoch 00003: val_loss improved from 0.38478 to 0.38385, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4644 - dice_coef: 0.1765 - val_loss: 0.3838 - val_dice_coef: 0.1436
# Epoch 5/50
#  - ETA: 0s - loss: 0.4615 - dice_coef: 0.1742Epoch 00004: val_loss did not improve
#  - 3s - loss: 0.4641 - dice_coef: 0.1746 - val_loss: 0.3873 - val_dice_coef: 0.1473
# Epoch 6/50
#  - ETA: 0s - loss: 0.4632 - dice_coef: 0.1809Epoch 00005: val_loss did not improve
#  - 3s - loss: 0.4636 - dice_coef: 0.1811 - val_loss: 0.3868 - val_dice_coef: 0.1472
# Epoch 7/50
#  - ETA: 0s - loss: 0.4636 - dice_coef: 0.1788Epoch 00006: val_loss did not improve
#  - 3s - loss: 0.4638 - dice_coef: 0.1789 - val_loss: 0.3862 - val_dice_coef: 0.1468
# Epoch 8/50
#  - ETA: 0s - loss: 0.4642 - dice_coef: 0.1803Epoch 00007: val_loss did not improve
#  - 3s - loss: 0.4633 - dice_coef: 0.1798 - val_loss: 0.3853 - val_dice_coef: 0.1459
# Epoch 9/50
#  - ETA: 0s - loss: 0.4648 - dice_coef: 0.1778Epoch 00008: val_loss did not improve
#  - 3s - loss: 0.4636 - dice_coef: 0.1771 - val_loss: 0.3845 - val_dice_coef: 0.1452
# Epoch 10/50
#  - ETA: 0s - loss: 0.4641 - dice_coef: 0.1779Epoch 00009: val_loss did not improve
#  - 3s - loss: 0.4633 - dice_coef: 0.1776 - val_loss: 0.3847 - val_dice_coef: 0.1455
# Epoch 11/50
#  - ETA: 0s - loss: 0.4640 - dice_coef: 0.1806Epoch 00010: val_loss improved from 0.38385 to 0.38376, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 5s - loss: 0.4630 - dice_coef: 0.1800 - val_loss: 0.3838 - val_dice_coef: 0.1448
# Epoch 12/50
#  - ETA: 0s - loss: 0.4626 - dice_coef: 0.1765Epoch 00011: val_loss did not improve
#  - 3s - loss: 0.4631 - dice_coef: 0.1767 - val_loss: 0.3853 - val_dice_coef: 0.1467
# Epoch 13/50
#  - ETA: 0s - loss: 0.4636 - dice_coef: 0.1812Epoch 00012: val_loss did not improve
#  - 3s - loss: 0.4626 - dice_coef: 0.1806 - val_loss: 0.3841 - val_dice_coef: 0.1456
# Epoch 14/50
#  - ETA: 0s - loss: 0.4624 - dice_coef: 0.1754Epoch 00013: val_loss did not improve
#  - 3s - loss: 0.4632 - dice_coef: 0.1756 - val_loss: 0.3848 - val_dice_coef: 0.1465
# Epoch 15/50
#  - ETA: 0s - loss: 0.4640 - dice_coef: 0.1772Epoch 00014: val_loss did not improve
#  - 3s - loss: 0.4629 - dice_coef: 0.1766 - val_loss: 0.3839 - val_dice_coef: 0.1458
# Epoch 16/50
#  - ETA: 0s - loss: 0.4615 - dice_coef: 0.1774Epoch 00015: val_loss did not improve
#  - 3s - loss: 0.4626 - dice_coef: 0.1777 - val_loss: 0.3855 - val_dice_coef: 0.1475
# Epoch 17/50
#  - ETA: 0s - loss: 0.4632 - dice_coef: 0.1784Epoch 00016: val_loss did not improve
#  - 3s - loss: 0.4624 - dice_coef: 0.1780 - val_loss: 0.3848 - val_dice_coef: 0.1471
# Epoch 18/50
#  - ETA: 0s - loss: 0.4635 - dice_coef: 0.1758Epoch 00017: val_loss did not improve
#  - 3s - loss: 0.4625 - dice_coef: 0.1753 - val_loss: 0.3843 - val_dice_coef: 0.1466
# Epoch 19/50
#  - ETA: 0s - loss: 0.4626 - dice_coef: 0.1824Epoch 00018: val_loss improved from 0.38376 to 0.38315, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4618 - dice_coef: 0.1820 - val_loss: 0.3832 - val_dice_coef: 0.1456
# Epoch 20/50
#  - ETA: 0s - loss: 0.4609 - dice_coef: 0.1782Epoch 00019: val_loss did not improve
#  - 3s - loss: 0.4618 - dice_coef: 0.1784 - val_loss: 0.3844 - val_dice_coef: 0.1472
# Epoch 21/50
#  - ETA: 0s - loss: 0.4625 - dice_coef: 0.1802Epoch 00020: val_loss did not improve
#  - 3s - loss: 0.4617 - dice_coef: 0.1798 - val_loss: 0.3835 - val_dice_coef: 0.1466
# Epoch 22/50
#  - ETA: 0s - loss: 0.4595 - dice_coef: 0.1768Epoch 00021: val_loss did not improve
#  - 3s - loss: 0.4620 - dice_coef: 0.1773 - val_loss: 0.3858 - val_dice_coef: 0.1490
# Epoch 23/50
#  - ETA: 0s - loss: 0.4623 - dice_coef: 0.1824Epoch 00022: val_loss improved from 0.38315 to 0.38276, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4613 - dice_coef: 0.1819 - val_loss: 0.3828 - val_dice_coef: 0.1464
# Epoch 24/50
#  - ETA: 0s - loss: 0.4622 - dice_coef: 0.1794Epoch 00023: val_loss improved from 0.38276 to 0.38171, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4614 - dice_coef: 0.1790 - val_loss: 0.3817 - val_dice_coef: 0.1454
# Epoch 25/50
#  - ETA: 0s - loss: 0.4619 - dice_coef: 0.1796Epoch 00024: val_loss improved from 0.38171 to 0.38154, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4610 - dice_coef: 0.1792 - val_loss: 0.3815 - val_dice_coef: 0.1456
# Epoch 26/50
#  - ETA: 0s - loss: 0.4622 - dice_coef: 0.1778Epoch 00025: val_loss did not improve
#  - 3s - loss: 0.4611 - dice_coef: 0.1772 - val_loss: 0.3818 - val_dice_coef: 0.1465
# Epoch 27/50
#  - ETA: 0s - loss: 0.4586 - dice_coef: 0.1769Epoch 00026: val_loss did not improve
#  - 3s - loss: 0.4609 - dice_coef: 0.1774 - val_loss: 0.3850 - val_dice_coef: 0.1498
# Epoch 28/50
#  - ETA: 0s - loss: 0.4603 - dice_coef: 0.1798Epoch 00027: val_loss did not improve
#  - 3s - loss: 0.4610 - dice_coef: 0.1800 - val_loss: 0.3838 - val_dice_coef: 0.1486
# Epoch 29/50
#  - ETA: 0s - loss: 0.4590 - dice_coef: 0.1831Epoch 00028: val_loss did not improve
#  - 3s - loss: 0.4599 - dice_coef: 0.1833 - val_loss: 0.3841 - val_dice_coef: 0.1495
# Epoch 30/50
#  - ETA: 0s - loss: 0.4593 - dice_coef: 0.1828Epoch 00029: val_loss did not improve
#  - 3s - loss: 0.4600 - dice_coef: 0.1830 - val_loss: 0.3841 - val_dice_coef: 0.1503
# Epoch 31/50
#  - ETA: 0s - loss: 0.4582 - dice_coef: 0.1844Epoch 00030: val_loss did not improve
#  - 3s - loss: 0.4593 - dice_coef: 0.1847 - val_loss: 0.3843 - val_dice_coef: 0.1510
# Epoch 32/50
#  - ETA: 0s - loss: 0.4603 - dice_coef: 0.1850Epoch 00031: val_loss did not improve
#  - 3s - loss: 0.4595 - dice_coef: 0.1846 - val_loss: 0.3825 - val_dice_coef: 0.1495
# Epoch 33/50
#  - ETA: 0s - loss: 0.4600 - dice_coef: 0.1829Epoch 00032: val_loss improved from 0.38154 to 0.38141, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4592 - dice_coef: 0.1824 - val_loss: 0.3814 - val_dice_coef: 0.1486
# Epoch 34/50
#  - ETA: 0s - loss: 0.4598 - dice_coef: 0.1840Epoch 00033: val_loss improved from 0.38141 to 0.38067, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4589 - dice_coef: 0.1836 - val_loss: 0.3807 - val_dice_coef: 0.1480
# Epoch 35/50
#  - ETA: 0s - loss: 0.4582 - dice_coef: 0.1824Epoch 00034: val_loss did not improve
#  - 3s - loss: 0.4589 - dice_coef: 0.1826 - val_loss: 0.3825 - val_dice_coef: 0.1504
# Epoch 36/50
#  - ETA: 0s - loss: 0.4598 - dice_coef: 0.1860Epoch 00035: val_loss improved from 0.38067 to 0.38063, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 5s - loss: 0.4588 - dice_coef: 0.1855 - val_loss: 0.3806 - val_dice_coef: 0.1492
# Epoch 37/50
#  - ETA: 0s - loss: 0.4580 - dice_coef: 0.1828Epoch 00036: val_loss did not improve
#  - 3s - loss: 0.4585 - dice_coef: 0.1830 - val_loss: 0.3808 - val_dice_coef: 0.1501
# Epoch 38/50
#  - ETA: 0s - loss: 0.4586 - dice_coef: 0.1870Epoch 00037: val_loss improved from 0.38063 to 0.37974, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4576 - dice_coef: 0.1865 - val_loss: 0.3797 - val_dice_coef: 0.1494
# Epoch 39/50
#  - ETA: 0s - loss: 0.4590 - dice_coef: 0.1868Epoch 00038: val_loss improved from 0.37974 to 0.37903, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4579 - dice_coef: 0.1861 - val_loss: 0.3790 - val_dice_coef: 0.1494
# Epoch 40/50
#  - ETA: 0s - loss: 0.4585 - dice_coef: 0.1857Epoch 00039: val_loss improved from 0.37903 to 0.37873, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 5s - loss: 0.4574 - dice_coef: 0.1850 - val_loss: 0.3787 - val_dice_coef: 0.1496
# Epoch 41/50
#  - ETA: 0s - loss: 0.4565 - dice_coef: 0.1846Epoch 00040: val_loss did not improve
#  - 3s - loss: 0.4572 - dice_coef: 0.1848 - val_loss: 0.3802 - val_dice_coef: 0.1520
# Epoch 42/50
#  - ETA: 0s - loss: 0.4560 - dice_coef: 0.1860Epoch 00041: val_loss did not improve
#  - 3s - loss: 0.4571 - dice_coef: 0.1862 - val_loss: 0.3812 - val_dice_coef: 0.1531
# Epoch 43/50
#  - ETA: 0s - loss: 0.4561 - dice_coef: 0.1874Epoch 00042: val_loss did not improve
#  - 3s - loss: 0.4568 - dice_coef: 0.1876 - val_loss: 0.3806 - val_dice_coef: 0.1529
# Epoch 44/50
#  - ETA: 0s - loss: 0.4574 - dice_coef: 0.1878Epoch 00043: val_loss did not improve
#  - 3s - loss: 0.4567 - dice_coef: 0.1874 - val_loss: 0.3794 - val_dice_coef: 0.1519
# Epoch 45/50
#  - ETA: 0s - loss: 0.4550 - dice_coef: 0.1876Epoch 00044: val_loss did not improve
#  - 3s - loss: 0.4559 - dice_coef: 0.1878 - val_loss: 0.3812 - val_dice_coef: 0.1543
# Epoch 46/50
#  - ETA: 0s - loss: 0.4551 - dice_coef: 0.1889Epoch 00045: val_loss did not improve
#  - 3s - loss: 0.4562 - dice_coef: 0.1891 - val_loss: 0.3806 - val_dice_coef: 0.1536
# Epoch 47/50
#  - ETA: 0s - loss: 0.4554 - dice_coef: 0.1880Epoch 00046: val_loss did not improve
#  - 3s - loss: 0.4563 - dice_coef: 0.1882 - val_loss: 0.3805 - val_dice_coef: 0.1545
# Epoch 48/50
#  - ETA: 0s - loss: 0.4547 - dice_coef: 0.1922Epoch 00047: val_loss did not improve
#  - 3s - loss: 0.4552 - dice_coef: 0.1923 - val_loss: 0.3795 - val_dice_coef: 0.1544
# Epoch 49/50
#  - ETA: 0s - loss: 0.4566 - dice_coef: 0.1899Epoch 00048: val_loss improved from 0.37873 to 0.37781, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 4s - loss: 0.4556 - dice_coef: 0.1893 - val_loss: 0.3778 - val_dice_coef: 0.1523
# Epoch 50/50
#  - ETA: 0s - loss: 0.4562 - dice_coef: 0.1904Epoch 00049: val_loss improved from 0.37781 to 0.37706, saving model to saved_models/weights.best.xception_interim.hdf5
#  - 5s - loss: 0.4553 - dice_coef: 0.1898 - val_loss: 0.3771 - val_dice_coef: 0.1522

# %%
def Xception_detect_nuclei(img_path):
    # obtain predicted vector
    predicted_vector = Xception_starter_model.predict(path_to_tensor(img_path))
    # return dog breed that is predicted by the model
    return predicted_vector

# %%
def path_to_image3(img_path):
    image = io.imread(img_path)
    #transform image to (150,150)
    image = resize(image, (img_height, img_width), mode='constant')
    #rgba to rgb
    try:
        image = rgba2rgb(image)
    except:
        image = np.expand_dims(image,axis=-1)
    image = img_as_float(image)
    return image

# %%
## Sanity Check:
predImage = Xception_detect_nuclei(train_files[0])
plot_image(path_to_image(train_files[0]))
plt.imshow(predImage[0])
plt.show()
# Out:
# (150, 150, 3)
